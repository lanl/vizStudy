# %%
import cv2
from skimage.metrics import structural_similarity as ssim

# %%
import matplotlib.pyplot as plt

# %%
img1_name = "/home/pascal/projects/project_libra/data/orig.png"
img2_name = "/home/pascal/projects/project_libra/data/compressed.png"

# %%
im1 = cv2.imread(img1_name)
im2 = cv2.imread(img2_name)

# %%
hsv_img1 = cv2.cvtColor(im1, cv2.COLOR_BGR2HSV)
hsv_img2 = cv2.cvtColor(im2, cv2.COLOR_BGR2HSV)

# %%
plt.imshow(cv2.cvtColor(im1, cv2.COLOR_BGR2RGB))

# %%
hsv_img1_split = cv2.split(hsv_img1)

# %%
plt.imshow(cv2.cvtColor(hsv_img1_split[0], cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(hsv_img1_split[1], cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(hsv_img1_split[2], cv2.COLOR_BGR2RGB))

# %%
diff_img = cv2.subtract(im1, im2)

# %%
plt.imshow(cv2.cvtColor(diff_img, cv2.COLOR_BGR2RGB))
